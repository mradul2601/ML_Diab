# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
data=pd.read_csv('data/Pima_Indian_diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.600000
# 1            1.0     85.0           66.0           29.0      0.0  26.600000
# 2            8.0    183.0           64.0            0.0      0.0  23.300000
# 3            1.0     89.0           66.0           23.0     94.0  19.179925
# 4            0.0    137.0           40.0           35.0    168.0  43.100000
# ..           ...      ...            ...            ...      ...        ...
# 763         10.0    101.0           76.0           48.0    180.0  32.900000
# 764          2.0    122.0           70.0           27.0      0.0  36.800000
# 765          5.0    121.0           72.0           23.0    112.0  26.200000
# 766          1.0    126.0           60.0            0.0      0.0  30.100000
# 767          1.0     93.0           70.0           31.0      0.0  30.400000
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 4                       2.288  33.0        1
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [757 rows x 9 columns]

# %%
data.Pregnancies[data.Pregnancies < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.Glucose[data.Glucose< 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.BloodPressure[data.BloodPressure < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.600000
# 1            1.0     85.0           66.0           29.0      0.0  26.600000
# 2            8.0    183.0           64.0            0.0      0.0  23.300000
# 3            1.0     89.0           66.0           23.0     94.0  19.179925
# 4            0.0    137.0           40.0           35.0    168.0  43.100000
# ..           ...      ...            ...            ...      ...        ...
# 763         10.0    101.0           76.0           48.0    180.0  32.900000
# 764          2.0    122.0           70.0           27.0      0.0  36.800000
# 765          5.0    121.0           72.0           23.0    112.0  26.200000
# 766          1.0    126.0           60.0            0.0      0.0  30.100000
# 767          1.0     93.0           70.0           31.0      0.0  30.400000
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 4                       2.288  33.0        1
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [757 rows x 9 columns]

# %%
data.SkinThickness[data.SkinThickness < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.Insulin[data.Insulin < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.BMI[data.BMI < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6.0    148.0           72.0           35.0      0.0   33
# 1            1.0     85.0           66.0           29.0      0.0   26
# 2            8.0    183.0           64.0            0.0      0.0   23
# 3            1.0     89.0           66.0           23.0     94.0   19
# 4            0.0    137.0           40.0           35.0    168.0   43
# ..           ...      ...            ...            ...      ...  ...
# 763         10.0    101.0           76.0           48.0    180.0   32
# 764          2.0    122.0           70.0           27.0      0.0   36
# 765          5.0    121.0           72.0           23.0    112.0   26
# 766          1.0    126.0           60.0            0.0      0.0   30
# 767          1.0     93.0           70.0           31.0      0.0   30
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 4                       2.288  33.0        1
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [731 rows x 9 columns]

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6.0    148.0           72.0           35.0      0.0   33
# 1            1.0     85.0           66.0           29.0      0.0   26
# 2            8.0    183.0           64.0            0.0      0.0   23
# 3            1.0     89.0           66.0           23.0     94.0   19
# 4            0.0    137.0           40.0           35.0    168.0   43
# ..           ...      ...            ...            ...      ...  ...
# 763         10.0    101.0           76.0           48.0    180.0   32
# 764          2.0    122.0           70.0           27.0      0.0   36
# 765          5.0    121.0           72.0           23.0    112.0   26
# 766          1.0    126.0           60.0            0.0      0.0   30
# 767          1.0     93.0           70.0           31.0      0.0   30
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 4                       2.288  33.0        1
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [731 rows x 9 columns]

# %%
data.shape
# Out:
# (757, 9)

# %%
data.BMI.isnull().sum()
# Out:
# 0

# %%
BMI_mean = data.BMI.mean()

# %%
data.BMI.fillna(value = BMI_mean, inplace = True)
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/pandas/core/generic.py:6288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
data.BMI.isnull().sum()
# Out:
# 0

# %%
data.BMI=data.BMI.astype(int)
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/pandas/core/generic.py:5209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data.SkinThickness.isnull().sum()
# Out:
# 22

# %%
skin_mean = data.SkinThickness.mean()

# %%
data.SkinThickness.fillna(value = skin_mean, inplace = True)

# %%
data.SkinThickness.isnull().sum()
# Out:
# 0

# %%
data.Age.isnull().sum()
# Out:
# 18

# %%
age_mean = data.Age.mean()

# %%
data.Age.fillna(value = age_mean, inplace = True)

# %%
data.Age.isnull().sum()
# Out:
# 0

# %%
data.Pregnancies=data.Pregnancies.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-7f02d0d70d1b> in <module>
# ----> 1 data.Pregnancies=data.Pregnancies.astype(int)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5881             # else, only a single dtype is given
#    5882             new_data = self._data.astype(
# -> 5883                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5884             )
#    5885             return self._constructor(new_data).__finalize__(self)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     555
#     556     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 557         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     558
#     559     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     639                     # _astype_nansafe works fine with 1-d only
#     640                     vals1d = values.ravel()
# --> 641                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     642
#     643                 # TODO(extension)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     698         if not np.isfinite(arr).all():
#     699             raise ValueError(
# --> 700                 "Cannot convert non-finite values (NA or inf) to " "integer"
#     701             )
#     702
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
data.Age=data.Age.astype(int)

# %%
data.Glucose.isnull().sum()
# Out:
# 0

# %%
gl_mean = data.Glucose.mean()

# %%
data.Glucose.fillna(value = gl_mean, inplace = True)

# %%
data.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6.0    148.0           72.0           35.0      0.0   33
# 1            1.0     85.0           66.0           29.0      0.0   26
# 2            8.0    183.0           64.0            0.0      0.0   23
# 3            1.0     89.0           66.0           23.0     94.0   19
# 4            0.0    137.0           40.0           35.0    168.0   43
# ..           ...      ...            ...            ...      ...  ...
# 763         10.0    101.0           76.0           48.0    180.0   32
# 764          2.0    122.0           70.0           27.0      0.0   36
# 765          5.0    121.0           72.0           23.0    112.0   26
# 766          1.0    126.0           60.0            0.0      0.0   30
# 767          1.0     93.0           70.0           31.0      0.0   30
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 4                       2.288  33.0        1
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [731 rows x 9 columns]

# %%
corr = data.corr()
print(corr)
sns.heatmap(corr, 
         xticklabels=corr.columns, 
         yticklabels=corr.columns)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.082517       0.121174      -0.102504
# Glucose                      0.082517  1.000000       0.139129       0.062001
# BloodPressure                0.121174  0.139129       1.000000       0.203944
# SkinThickness               -0.102504  0.062001       0.203944       1.000000
# Insulin                     -0.105746  0.320502       0.089234       0.427013
# BMI                         -0.015202  0.183888       0.280466       0.382122
# DiabetesPedigreeFunction    -0.042244  0.125774       0.039727       0.187588
# Age                          0.465542  0.245729       0.227612      -0.119916
# Outcome                      0.189863  0.463523       0.063825       0.078870
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.105746 -0.015202                 -0.042244
# Glucose                   0.320502  0.183888                  0.125774
# BloodPressure             0.089234  0.280466                  0.039727
# SkinThickness             0.427013  0.382122                  0.187588
# Insulin                   1.000000  0.190353                  0.183647
# BMI                       0.190353  1.000000                  0.149603
# DiabetesPedigreeFunction  0.183647  0.149603                  1.000000
# Age                      -0.053498  0.020426                  0.029664
# Outcome                   0.121664  0.282696                  0.172161
#
#                                Age   Outcome
# Pregnancies               0.465542  0.189863
# Glucose                   0.245729  0.463523
# BloodPressure             0.227612  0.063825
# SkinThickness            -0.119916  0.078870
# Insulin                  -0.053498  0.121664
# BMI                       0.020426  0.282696
# DiabetesPedigreeFunction  0.029664  0.172161
# Age                       1.000000  0.217091
# Outcome                   0.217091  1.000000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-87d53881c7de> in <module>
#       1 corr = data.corr()
#       2 print(corr)
# ----> 3 sns.heatmap(corr,
#       4          xticklabels=corr.columns,
#       5          yticklabels=corr.columns)
#
# NameError: name 'sns' is not defined

# %%
data.shape
# Out:
# (731, 9)

# %%
dfTrain = data[:600]
dfTest = data[601:720]
dfCheck = data[721:]

# %%
trainLabel = np.asarray(dfTrain['Outcome'])
trainData = np.asarray(dfTrain.drop('Outcome',1))
testLabel = np.asarray(dfTest['Outcome'])
testData = np.asarray(dfTest.drop('Outcome',1))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 731 non-null float64
# Glucose                     731 non-null float64
# BloodPressure               731 non-null float64
# SkinThickness               731 non-null float64
# Insulin                     731 non-null float64
# BMI                         731 non-null int64
# DiabetesPedigreeFunction    731 non-null float64
# Age                         731 non-null float64
# Outcome                     731 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 57.1 KB

# %%
data=data.dropna()

# %%
means = np.mean(trainData, axis=0)
stds = np.std(trainData, axis=0)
trainData = (trainData - means)/stds
testData = (testData - means)/stds



# drop rows with missing values

# %%
trainData<
# Out:
#   File "<ipython-input-83-d83b278f57d3>", line 1
#     trainData<
#               ^
# SyntaxError: invalid syntax

# %%
data.shape
# Out:
# (731, 9)

# %%
from sklearn import svm

# %%
diabetesCheck = LogisticRegression()
diabetesCheck.fit(trainData, trainLabel)
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6.0    148.0           72.0           35.0      0.0   33
# 1            1.0     85.0           66.0           29.0      0.0   26
# 2            8.0    183.0           64.0            0.0      0.0   23
# 3            1.0     89.0           66.0           23.0     94.0   19
# 4            0.0    137.0           40.0           35.0    168.0   43
# ..           ...      ...            ...            ...      ...  ...
# 763         10.0    101.0           76.0           48.0    180.0   32
# 764          2.0    122.0           70.0           27.0      0.0   36
# 765          5.0    121.0           72.0           23.0    112.0   26
# 766          1.0    126.0           60.0            0.0      0.0   30
# 767          1.0     93.0           70.0           31.0      0.0   30
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 4                       2.288  33.0        1
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [731 rows x 9 columns]

# %%
accuracy = diabetesCheck.score(testData, testLabel)
print("accuracy = ", accuracy * 100, "%")
# Out:
# accuracy =  72.26890756302521 %
