#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 5                       0.201  30.0        0
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [621 rows x 9 columns]

# %%
data.BMI.isnull().sum()
# Out:
# 0

# %%
BMI_mean = data.BMI.mean()

# %%
data.BMI.fillna(value = BMI_mean, inplace = True)

# %%
data.BMI.isnull().sum()
# Out:
# 0

# %%
data.BMI=data.BMI.astype(int)

# %%
data.SkinThickness.isnull().sum()
# Out:
# 16

# %%
skin_mean = data.SkinThickness.mean()

# %%
data.SkinThickness.fillna(value = skin_mean, inplace = True)

# %%
data.SkinThickness.isnull().sum()
# Out:
# 0

# %%
data.Age.isnull().sum()
# Out:
# 16

# %%
age_mean = data.Age.mean()

# %%
data.Age.fillna(value = age_mean, inplace = True)

# %%
data.Age.isnull().sum()
# Out:
# 0

# %%
data.Pregnancies=data.Pregnancies.astype(int)

# %%
data.Age=data.Age.astype(int)

# %%
data.Glucose.isnull().sum()
# Out:
# 13

# %%
gl_mean = data.Glucose.mean()

# %%
data.Glucose.fillna(value = gl_mean, inplace = True)

# %%
data.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0              6    148.0           72.0           35.0      0.0   33
# 1              1     85.0           66.0           29.0      0.0   26
# 2              8    183.0           64.0            0.0      0.0   23
# 3              1     89.0           66.0           23.0     94.0   19
# 5              5    116.0           74.0            0.0      0.0   25
# ..           ...      ...            ...            ...      ...  ...
# 763           10    101.0           76.0           48.0    180.0   32
# 764            2    122.0           70.0           27.0      0.0   36
# 765            5    121.0           72.0           23.0    112.0   26
# 766            1    126.0           60.0            0.0      0.0   30
# 767            1     93.0           70.0           31.0      0.0   30
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 5                       0.201   30        0
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [621 rows x 9 columns]

# %%
corr = data.corr()
print(corr)
sns.heatmap(corr, 
         xticklabels=corr.columns, 
         yticklabels=corr.columns)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.122079       0.128777      -0.100105
# Glucose                      0.122079  1.000000       0.156452       0.036794
# BloodPressure                0.128777  0.156452       1.000000       0.182649
# SkinThickness               -0.100105  0.036794       0.182649       1.000000
# Insulin                     -0.118074  0.331236       0.075477       0.421340
# BMI                          0.056492  0.179791       0.306866       0.357922
# DiabetesPedigreeFunction    -0.021918  0.095693       0.062693       0.184532
# Age                          0.490289  0.274201       0.246168      -0.095954
# Outcome                      0.233423  0.446902       0.093883       0.075642
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.118074  0.056492                 -0.021918
# Glucose                   0.331236  0.179791                  0.095693
# BloodPressure             0.075477  0.306866                  0.062693
# SkinThickness             0.421340  0.357922                  0.184532
# Insulin                   1.000000  0.176955                  0.222223
# BMI                       0.176955  1.000000                  0.151768
# DiabetesPedigreeFunction  0.222223  0.151768                  1.000000
# Age                      -0.025436  0.040300                  0.027723
# Outcome                   0.143351  0.279609                  0.164363
#
#                                Age   Outcome
# Pregnancies               0.490289  0.233423
# Glucose                   0.274201  0.446902
# BloodPressure             0.246168  0.093883
# SkinThickness            -0.095954  0.075642
# Insulin                  -0.025436  0.143351
# BMI                       0.040300  0.279609
# DiabetesPedigreeFunction  0.027723  0.164363
# Age                       1.000000  0.240580
# Outcome                   0.240580  1.000000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-87d53881c7de> in <module>
#       1 corr = data.corr()
#       2 print(corr)
# ----> 3 sns.heatmap(corr,
#       4          xticklabels=corr.columns,
#       5          yticklabels=corr.columns)
#
# NameError: name 'sns' is not defined

# %%
data.shape
# Out:
# (621, 9)

# %%
dfTrain = data[:550]
dfTest = data[551:600]
dfCheck = data[601:]

# %%
trainLabel = np.asarray(dfTrain['Outcome'])
trainData = np.asarray(dfTrain.drop('Outcome',1))
testLabel = np.asarray(dfTest['Outcome'])
testData = np.asarray(dfTest.drop('Outcome',1))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 621 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 621 non-null int64
# Glucose                     621 non-null float64
# BloodPressure               621 non-null float64
# SkinThickness               621 non-null float64
# Insulin                     621 non-null float64
# BMI                         621 non-null int64
# DiabetesPedigreeFunction    621 non-null float64
# Age                         621 non-null int64
# Outcome                     621 non-null int64
# dtypes: float64(5), int64(4)
# memory usage: 48.5 KB

# %%
means = np.mean(trainData, axis=0)
stds = np.std(trainData, axis=0)
trainData = (trainData - means)/stds
testData = (testData - means)/stds



# drop rows with missing values

# %%
trainData<
# Out:
#   File "<ipython-input-109-d83b278f57d3>", line 1
#     trainData<
#               ^
# SyntaxError: invalid syntax

# %%
from sklearn import svm

# %%
diabetesCheck = LogisticRegression()
diabetesCheck.fit(trainData, trainLabel)
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0              6    148.0           72.0           35.0      0.0   33
# 1              1     85.0           66.0           29.0      0.0   26
# 2              8    183.0           64.0            0.0      0.0   23
# 3              1     89.0           66.0           23.0     94.0   19
# 5              5    116.0           74.0            0.0      0.0   25
# ..           ...      ...            ...            ...      ...  ...
# 763           10    101.0           76.0           48.0    180.0   32
# 764            2    122.0           70.0           27.0      0.0   36
# 765            5    121.0           72.0           23.0    112.0   26
# 766            1    126.0           60.0            0.0      0.0   30
# 767            1     93.0           70.0           31.0      0.0   30
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 5                       0.201   30        0
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [621 rows x 9 columns]

# %%
accuracy = diabetesCheck.score(testData, testLabel)
print("accuracy = ", accuracy * 100, "%")
# Out:
# accuracy =  73.46938775510205 %
