# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
data=pd.read_csv('data/Pima_Indian_diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.600000
# 1            1.0     85.0           66.0           29.0      0.0  26.600000
# 2            8.0    183.0           64.0            0.0      0.0  23.300000
# 3            1.0     89.0           66.0           23.0     94.0  19.179925
# 4            0.0    137.0           40.0           35.0    168.0  43.100000
# ..           ...      ...            ...            ...      ...        ...
# 763         10.0    101.0           76.0           48.0    180.0  32.900000
# 764          2.0    122.0           70.0           27.0      0.0  36.800000
# 765          5.0    121.0           72.0           23.0    112.0  26.200000
# 766          1.0    126.0           60.0            0.0      0.0  30.100000
# 767          1.0     93.0           70.0           31.0      0.0  30.400000
#
#      DiabetesPedigreeFunction   Age  Outcome
# ...

# %%
data.Pregnancies[data.Pregnancies < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.Glucose[data.Glucose< 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.BloodPressure[data.BloodPressure < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.600000
# 1            1.0     85.0           66.0           29.0      0.0  26.600000
# 2            8.0    183.0           64.0            0.0      0.0  23.300000
# 3            1.0     89.0           66.0           23.0     94.0  19.179925
# 4            0.0    137.0           40.0           35.0    168.0  43.100000
# ..           ...      ...            ...            ...      ...        ...
# 763         10.0    101.0           76.0           48.0    180.0  32.900000
# 764          2.0    122.0           70.0           27.0      0.0  36.800000
# 765          5.0    121.0           72.0           23.0    112.0  26.200000
# 766          1.0    126.0           60.0            0.0      0.0  30.100000
# 767          1.0     93.0           70.0           31.0      0.0  30.400000
#
#      DiabetesPedigreeFunction   Age  Outcome
# ...

# %%
data.SkinThickness[data.SkinThickness < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.Insulin[data.Insulin < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.BMI[data.BMI < 0] = 0
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.600000
# 1            1.0     85.0           66.0           29.0      0.0  26.600000
# 2            8.0    183.0           64.0            0.0      0.0  23.300000
# 3            1.0     89.0           66.0           23.0     94.0  19.179925
# 4            0.0    137.0           40.0           35.0    168.0  43.100000
# ..           ...      ...            ...            ...      ...        ...
# 763         10.0    101.0           76.0           48.0    180.0  32.900000
# 764          2.0    122.0           70.0           27.0      0.0  36.800000
# 765          5.0    121.0           72.0           23.0    112.0  26.200000
# 766          1.0    126.0           60.0            0.0      0.0  30.100000
# 767          1.0     93.0           70.0           31.0      0.0  30.400000
#
#      DiabetesPedigreeFunction   Age  Outcome
# ...

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.600000
# 1            1.0     85.0           66.0           29.0      0.0  26.600000
# 2            8.0    183.0           64.0            0.0      0.0  23.300000
# 3            1.0     89.0           66.0           23.0     94.0  19.179925
# 4            0.0    137.0           40.0           35.0    168.0  43.100000
# ..           ...      ...            ...            ...      ...        ...
# 763         10.0    101.0           76.0           48.0    180.0  32.900000
# 764          2.0    122.0           70.0           27.0      0.0  36.800000
# 765          5.0    121.0           72.0           23.0    112.0  26.200000
# 766          1.0    126.0           60.0            0.0      0.0  30.100000
# 767          1.0     93.0           70.0           31.0      0.0  30.400000
#
#      DiabetesPedigreeFunction   Age  Outcome
# ...

# %%
data.shape
# Out:
# (768, 9)

# %%
data.BMI.isnull().sum()
# Out:
# 11

# %%
BMI_mean = data.BMI.mean()

# %%
data.BMI.fillna(value = BMI_mean, inplace = True)

# %%
data.BMI.isnull().sum()
# Out:
# 0

# %%
data.BMI=data.BMI.astype(int)

# %%
data.SkinThickness.isnull().sum()
# Out:
# 22

# %%
skin_mean = data.SkinThickness.mean()

# %%
data.loc[data.SkinThickness==0.0,"SkinThickness"]=skin_mean

# %%
data.SkinThickness.fillna(value = skin_mean, inplace = True)

# %%
data.SkinThickness.isnull().sum()
# Out:
# 0

# %%
data.Age.isnull().sum()
# Out:
# 19

# %%
age_mean = data.Age.mean()

# %%
data.Age.fillna(value = age_mean, inplace = True)

# %%
data.Age.isnull().sum()
# Out:
# 0

# %%
data.Pregnancies=data.Pregnancies.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-7f02d0d70d1b> in <module>
# ----> 1 data.Pregnancies=data.Pregnancies.astype(int)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5881             # else, only a single dtype is given
#    5882             new_data = self._data.astype(
# -> 5883                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5884             )
#    5885             return self._constructor(new_data).__finalize__(self)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
data.Age=data.Age.astype(int)

# %%
data.Glucose.isnull().sum()
# Out:
# 16

# %%
gl_mean = data.Glucose.mean()

# %%
data.Glucose.fillna(value = gl_mean, inplace = True)

# %%
insulin_mean = data.Insulin.mean()

# %%
data.loc[data.Insulin==0.0,"Insulin"]=insulin_mean

# %%
data.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  BMI  \
# 0            6.0    148.0           72.0      35.000000   79.799479   33
# 1            1.0     85.0           66.0      29.000000   79.799479   26
# 2            8.0    183.0           64.0      20.358987   79.799479   23
# 3            1.0     89.0           66.0      23.000000   94.000000   19
# 4            0.0    137.0           40.0      35.000000  168.000000   43
# ..           ...      ...            ...            ...         ...  ...
# 763         10.0    101.0           76.0      48.000000  180.000000   32
# 764          2.0    122.0           70.0      27.000000   79.799479   36
# 765          5.0    121.0           72.0      23.000000  112.000000   26
# 766          1.0    126.0           60.0      20.358987   79.799479   30
# 767          1.0     93.0           70.0      31.000000   79.799479   30
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
corr = data.corr()
print(corr)
sns.heatmap(corr, 
         xticklabels=corr.columns, 
         yticklabels=corr.columns)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.088641       0.122548      -0.006750
# Glucose                      0.088641  1.000000       0.139927       0.155821
# BloodPressure                0.122548  0.139927       1.000000       0.174695
# SkinThickness               -0.006750  0.155821       0.174695       1.000000
# Insulin                     -0.040565  0.385892       0.076439       0.229524
# BMI                         -0.015074  0.182596       0.280019       0.460279
# DiabetesPedigreeFunction    -0.039072  0.123538       0.040077       0.151436
# Age                          0.463049  0.238085       0.228345      -0.008723
# Outcome                      0.195926  0.465235       0.063583       0.172367
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.040565 -0.015074                 -0.039072
# ...

# %%
data.shape
# Out:
# (742, 9)

# %%
dfTrain = data[:600]
dfTest = data[:200]
dfCheck = data[721:]

# %%
trainLabel = np.asarray(dfTrain['Outcome'])
trainData = np.asarray(dfTrain.drop('Outcome',1))
testLabel = np.asarray(dfTest['Outcome'])
testData = np.asarray(dfTest.drop('Outcome',1))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 742 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 742 non-null float64
# Glucose                     742 non-null float64
# BloodPressure               742 non-null float64
# SkinThickness               742 non-null float64
# Insulin                     742 non-null float64
# BMI                         742 non-null int64
# DiabetesPedigreeFunction    742 non-null float64
# Age                         742 non-null int64
# Outcome                     742 non-null int64
# dtypes: float64(6), int64(3)
# memory usage: 58.0 KB

# %%
data=data.dropna()

# %%
means = np.mean(trainData, axis=0)
stds = np.std(trainData, axis=0)
trainData = (trainData - means)/stds
testData = (testData - means)/stds



# drop rows with missing values

# %%
trainData<
# Out:
#   File "<ipython-input-174-d83b278f57d3>", line 1
#     trainData<
#               ^
# SyntaxError: invalid syntax

# %%
data.shape
# Out:
# (742, 9)

# %%
from sklearn.svm import SVC

# %%
diabetesCheck = LogisticRegression()
diabetesCheck.fit(trainData, trainLabel)
# Out:
# /home/iiitb/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  BMI  \
# 0            6.0    148.0           72.0      35.000000   79.799479   33
# 1            1.0     85.0           66.0      29.000000   79.799479   26
# 2            8.0    183.0           64.0      20.358987   79.799479   23
# 3            1.0     89.0           66.0      23.000000   94.000000   19
# 4            0.0    137.0           40.0      35.000000  168.000000   43
# ..           ...      ...            ...            ...         ...  ...
# 763         10.0    101.0           76.0      48.000000  180.000000   32
# 764          2.0    122.0           70.0      27.000000   79.799479   36
# 765          5.0    121.0           72.0      23.000000  112.000000   26
# 766          1.0    126.0           60.0      20.358987   79.799479   30
# 767          1.0     93.0           70.0      31.000000   79.799479   30
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
accuracy = diabetesCheck.score(testData, testLabel)
print("accuracy = ", accuracy * 100, "%")
# Out:
# accuracy =  75.0 %
